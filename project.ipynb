# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansalnakhan/TSA/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd

# %%
import numpy as np

# %%
dfs = pd.read_excel("/content/CS2_33_1_10_11 (2).xlsx", sheet_name=None)

# %%
dfs.keys()
# Out:
# dict_keys(['Info', 'Channel_1-006', 'Statistics_1-006'])

# %%
dfs['Channel_1-006']
# Out:
#        Data_Point   Test_Time(s)           Date_Time  Step_Time(s)  \
# 0               1      30.000402 2011-01-03 10:38:25     30.000402
# 1               2      60.015662 2011-01-03 10:38:55     60.015662
# 2               3      90.030747 2011-01-03 10:39:25     90.030747
# 3               4     120.014300 2011-01-03 10:39:55    120.014301
# 4               5     137.905777 2011-01-03 10:40:13     17.890985
# ...           ...            ...                 ...           ...
# 15570       15571  604676.478553 2011-01-10 10:36:55   3470.178041
# 15571       15572  604678.009530 2011-01-10 10:36:56   3471.709018
# 15572       15573  604738.053710 2011-01-10 10:37:56     60.014661
# 15573       15574  604738.271744 2011-01-10 10:37:57      0.187428
# 15574       15575  604743.099943 2011-01-10 10:38:02      5.015627
#
#        Step_Index  Cycle_Index  Current(A)  Voltage(V)  Charge_Capacity(Ah)  \
# 0               1            1    0.000000    4.118745             0.000000
# ...

# %%
from sklearn.decomposition import PCA

# %%
pcamodel=PCA(n_components=2)

# %%
principalcomponents=pcamodel.fit_transform(dfs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-5bd0ad894866> in <module>()
# ----> 1 principalcomponents=pcamodel.fit_transform(dfs)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     405         C-ordered array, use 'np.ascontiguousarray'.
#     406         """
# --> 407         U, S, Vt = self._fit(X)
#     408         U = U[:, : self.n_components_]
#     409
#
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     429
#     430         X = self._validate_data(
# --> 431             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     432         )
#     433
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
