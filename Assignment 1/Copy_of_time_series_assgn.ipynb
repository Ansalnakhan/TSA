# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansalnakhan/TSA/blob/main/Assignment%201/Copy_of_time_series_assgn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
series=pd.read_csv('/content/daily-min-temperatures.csv',index_col='Date')
series
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
#PLOT THE DATA

# %%
from matplotlib import pyplot
series.plot(figsize=(12,10))
pyplot.title("daily temperature")
pyplot.show()

# %%
#PLOT ACF

# %%
from statsmodels.graphics.tsaplots import plot_acf
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plot_acf(series)
pyplot.show()

# %%
#PLOT PACF

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(series,lags=45)
pyplot.show()

# %%
series2=pd.read_csv('/content/daily-total-female-births.csv',index_col='Date')

series2
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
series2.plot(figsize=(20,8))
pyplot.show()

# %%
plot_acf(series2)
pyplot.show()

# %%
plot_pacf(series2)
pyplot.show()

# %%
#CHECK STATIONARITY

# %%
#1. PLOT HISTOGRAM

# %%
series.hist()
pyplot.title('daily temperature')
pyplot.show
# Out:
# <function matplotlib.pyplot.show>

# %%
series2.hist()
pyplot.title('female birth')
pyplot.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#MEAN AND VARIANCE

# %%
x=series2.values
split=round(len(x)/2)
x1,x2=x[0:split],x[split:]
mean1,mean2=x1.mean(),x2.mean()
var1,var2=x1.var(),x2.var()

# %%
print(mean1,mean2)
# Out:
# 39.76373626373626 44.185792349726775

# %%
print(var1,var2)
# Out:
# 49.21341021615746 48.708650601690096

# %%
series3=pd.read_csv('/content/airline-passengers.csv',index_col='Month')
series3
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %%
series3.plot(figsize=(20,8))
pyplot.show()

# %%
plot_acf(series3)
pyplot.show()

# %%
plot_pacf(series3)
pyplot.show()

# %%
series3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3be7a8b750>]],
#       dtype=object)

# %%
x=series3.values
split=round(len(x)/2)
x1,x2=x[0:split],x[split:]
mean1,mean2=x1.mean(),x2.mean()
var1,var2=x1.var(),x2.var()

# %%
print(mean1,mean2)
# Out:
# 182.90277777777777 377.69444444444446

# %%
print(var1,var2)
# Out:
# 2244.0877700617284 7367.962191358024

# %%
#NON-STATIONARY TO STATIONARY

# %%
#LOG TRANSFORM

# %%
from numpy import log
x=series3.values
x=log(x)
pyplot.hist(x)
pyplot.show()
pyplot.plot(x)
pyplot.show()

# %%
x=series3.values
x=log(x)
split=round(len(x)/2)
x1,x2=x[0:split],x[split:]
mean1,mean2=x1.mean(),x2.mean()
var1,var2=x1.var(),x2.var()

# %%
print(mean1,mean2)
# Out:
# 5.17514614000377 5.909205777059973

# %%
print(var1,var2)
# Out:
# 0.06837486074542806 0.04926419375638024

# %%
#SQUARE ROOT TRANSFORM

# %%
series3=np.sqrt(series3)
series3
# Out:
#          Passengers
# Month
# 1949-01   10.583005
# 1949-02   10.862780
# 1949-03   11.489125
# 1949-04   11.357817
# 1949-05   11.000000
# ...             ...
# 1960-08   24.617067
# 1960-09   22.538855
# 1960-10   21.470911
# 1960-11   19.748418
# 1960-12   20.784610
#
# [144 rows x 1 columns]

# %%
X=series3.values
X=log(X)
split=round(len(X)/2)
X1,X2=X[0:split],X[split:]
mean1,mean2 = X1.mean(),X2.mean()
var1,var2 = X1.var(),X2.var()

# %%
print(mean1,mean2)
# Out:
# 2.587573070001885 2.9546028885299864

# %%
print(var1,var2)
# Out:
# 0.01709371518635701 0.012316048439095059

# %%
from statsmodels.tsa.stattools import adfuller

# %%
series2=pd.read_csv('/content/daily-total-female-births.csv',index_col='Date',squeeze=True)

# %%
series2=np.sqrt(series2)
x=series2.values
result=adfuller(x)

# %%
print(result)
# Out:
# (-4.898160545152449, 3.5163019948622685e-05, 6, 358, {'1%': -3.448748905151901, '5%': -2.8696473721448728, '10%': -2.5710891239349585}, 561.7040434825404)

# %%
series3=pd.read_csv('/content/airline-passengers.csv',index_col='Month',squeeze=True)

# %%
series3=np.sqrt(series3)
x=series3.values
result=adfuller(x)
print(result)
# Out:
# (-0.34585376771568216, 0.9187543217618357, 13, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 86.2558110746069)

# %%
#DIFFERENCING

# %%
series_3=pd.read_csv('/content/airline-passengers.csv')
series_3
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
series_3['diff_1'] = series_3['Passengers'].diff().fillna(0)
series_3['diff_2'] = series_3['Passengers'].diff(periods=2).fillna(0)
series_3
# Out:
#        Month  Passengers  diff_1  diff_2
# 0    1949-01         112     0.0     0.0
# 1    1949-02         118     6.0     0.0
# 2    1949-03         132    14.0    20.0
# 3    1949-04         129    -3.0    11.0
# 4    1949-05         121    -8.0   -11.0
# ..       ...         ...     ...     ...
# 139  1960-08         606   -16.0    71.0
# 140  1960-09         508   -98.0  -114.0
# 141  1960-10         461   -47.0  -145.0
# 142  1960-11         390   -71.0  -118.0
# 143  1960-12         432    42.0   -29.0
#
# [144 rows x 4 columns]

# %%
series_3["diff_1"].plot(figsize=(20,8))

# %%
series_3["diff_2"].plot(figsize=(20,8))

# %%
from statsmodels.tsa.stattools import adfuller
x=series_3['diff_1'].values
result=adfuller(x)
result
# Out:
# (-2.8891860694712546,
#  0.046620039206754685,
#  12,
#  131,
#  {'1%': -3.481281802271349,
#   '10%': -2.5786771965503177,
#   '5%': -2.883867891664528},
#  995.4013901509479)

# %%
#STATIONARITY TEST

# %%
#DICKEY-FULLER TEST

# %%
from statsmodels.tsa.stattools import adfuller

# %%
series2=pd.read_csv("/content/daily-total-female-births.csv",index_col='Date',squeeze=True)

# %%
x=series2.values
result=adfuller(x)

# %%
print(result)
# Out:
# (-4.808291253559765, 5.2434129901498554e-05, 6, 358, {'1%': -3.448748905151901, '5%': -2.8696473721448728, '10%': -2.5710891239349585}, 2343.8290926464197)

# %%
series3=pd.read_csv("/content/airline-passengers.csv",index_col='Month',squeeze=True)

# %%
x=series3.values
result=adfuller(x)

# %%
print(result)
# Out:
# (0.8153688792060472, 0.991880243437641, 13, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 996.6929308390189)

# %%
X=series3.values
X=log(X)
result=adfuller(X)
result
# Out:
# (-1.7170170891069603,
#  0.4223667747703914,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '10%': -2.578770059171598,
#   '5%': -2.8840418343195267},
#  -445.3990312497209)

# %%
series4=pd.read_csv('/content/Electric_Production.csv',index_col="DATE")
series4["Value"].plot(figsize=(20,8))
pyplot.show()

# %%
plot_acf(series4)
pyplot.show()

# %%
plot_pacf(series4)
pyplot.show()

# %%
series4=series4["Value"]
series4.hist()

# %%
X=series4.values
split=round(len(X)/2)
X1,X2=X[0:split],X[split:]
mean1,mean2 = X1.mean(),X2.mean()
var1,var2 = X1.var(),X2.var()

# %%
print(mean1,mean2)
print(var1,var2)
# Out:
# 77.40359141414143 100.23333819095478
# 121.47413934159292 90.38513111633041

# %%
series4=pd.read_csv('/content/Electric_Production.csv',index_col='DATE',squeeze=True)
X=series4.values
res=adfuller(X)
res
# Out:
# (-2.2569903500472366,
#  0.18621469116587053,
#  15,
#  381,
#  {'1%': -3.4476305904172904,
#   '10%': -2.570827146203181,
#   '5%': -2.869155980820355},
#  1840.8474501627156)

# %%
#LOG TRANSFORM

# %%
X=series4.values
X=log(X)
pyplot.hist(X)
pyplot.show()
pyplot.plot(X)
pyplot.show()

# %%
X=series4.values
X=log(X)
split=round(len(X)/2)
X1,X2=X[0:split],X[split:]
mean1,mean2 = X1.mean(),X2.mean()
var1,var2 = X1.var(),X2.var()
print(mean1,mean2)
print(var1,var2)
# Out:
# 4.338834602535242 4.6030515608191855
# 0.020525911997962793 0.008858102685572742

# %%
series4=pd.read_csv('/content/Electric_Production.csv',index_col='DATE',squeeze=True).dropna()
X=series4.values
X=log(X)
result=adfuller(X)
result
# Out:
# (-3.145360428107726,
#  0.02337340103298539,
#  15,
#  381,
#  {'1%': -3.4476305904172904,
#   '10%': -2.570827146203181,
#   '5%': -2.869155980820355},
#  -1627.1090225668188)

# %%
#SQUARE ROOT TRANSFORM

# %%
series4=np.sqrt(series4)
series4
# Out:
# DATE
# 01-01-1985     8.514999
# 02-01-1985     8.406664
# 03-01-1985     7.902544
# 04-01-1985     7.580989
# 05-01-1985     7.437412
#                 ...
# 09-01-2017     9.930529
# 10-01-2017     9.675417
# 11-01-2017     9.865896
# 12-01-2017    10.710798
# 01-01-2018    11.375623
# Name: Value, Length: 397, dtype: float64

# %%
series4=np.sqrt(series4)
X=series4.values
result=adfuller(X)
result
# Out:
# (-2.9137280870354263,
#  0.04377473916429312,
#  15,
#  381,
#  {'1%': -3.4476305904172904,
#   '10%': -2.570827146203181,
#   '5%': -2.869155980820355},
#  -1814.1128382841925)

# %%
#DIFFERENCING

# %%
series4=pd.read_csv('/content/Electric_Production.csv',index_col='DATE')
series4['diff_1'] = series4['Value'].diff().fillna(0)
series4['diff_2'] = series4['Value'].diff(periods=2).fillna(0)

# %%
series4["diff_1"].plot(figsize=(20,8))

# %%
series4["diff_2"].plot(figsize=(20,8))

# %%
x=series4['diff_1'].values
result=adfuller(x)
result
# Out:
# (-7.085380517071032,
#  4.5528288706901196e-10,
#  14,
#  382,
#  {'1%': -3.4475850438570115,
#   '10%': -2.5708164748773332,
#   '5%': -2.869135963767125},
#  1844.404694686257)

# %%
x=series4['diff_2'].values
result=adfuller(x)
result
# Out:
# (-7.211840260847052,
#  2.2243886575777325e-10,
#  13,
#  383,
#  {'1%': -3.44753973676872,
#   '10%': -2.57080585953957,
#   '5%': -2.8691160516676844},
#  1846.7670343787)
